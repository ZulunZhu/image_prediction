# %%
import os
import numpy as np
import xml.etree.ElementTree as ET
import matplotlib.pyplot as plt

# Your original readAmp() function (with plotting optionally disabled)
def readAmp(file):
    fileXml = file + '.xml'
    tree = ET.parse(fileXml)
    root = tree.getroot()
    width = int(root.find(".//property[@name='width']/value").text)
    length = int(root.find(".//property[@name='length']/value").text)
    with open(file, 'rb') as f:
        data = np.fromfile(f, dtype='<f4')
        data2 = data.reshape([length, width * 2])
        amp1 = data2[:, ::2]
        amp2 = data2[:, 1::2]
    # Optionally disable plotting for batch processing
    # plt.imshow(amp1, cmap='gray', vmin=0, vmax=5)
    # plt.colorbar(); plt.title("Amplitude 1"); plt.show()
    # plt.imshow(amp2, cmap='gray', vmin=0, vmax=5)
    # plt.colorbar(); plt.title("Amplitude 2"); plt.show()
    return amp1, amp2

# Modified readCor() function to return the coherence (edge) matrix
def readCor(file):
    fileXml = file + '.xml'
    tree = ET.parse(fileXml)
    root = tree.getroot()
    width = int(root.find(".//property[@name='width']/value").text)
    length = int(root.find(".//property[@name='length']/value").text)
    with open(file, 'rb') as f:
        data = np.fromfile(f, dtype=np.float32)
        data2 = data.reshape([length * 2, width])
        # Use the second band (odd rows) as the coherence (edge) feature
        cor = data2[1::2, :]
    return cor

def process_dataset(root_dir, base_filename='b01_16r4alks'):
    # Create a directory "image_data" in the current folder to store outputs
    save_dir = os.path.join(os.getcwd(), "image_data")
    if not os.path.exists(save_dir):
        os.makedirs(save_dir)
    
    # Dictionaries and lists to hold the node features and edge features
    date_to_feature = {}   # date (str) -> flattened amplitude vector
    edge_features_list = []  # list to store flattened edge features for each folder
    edge_node_pairs = []     # list to store corresponding (date1, date2) for each edge

    # Get a list of subdirectories with names like "cor_YYYYMMDD_YYYYMMDD"
    subdirs = [d for d in os.listdir(root_dir) if d.startswith("cor_") and os.path.isdir(os.path.join(root_dir, d))]
    subdirs.sort()  # sorting ensures that if the same date appears in multiple folders, the earliest is processed first

    for folder in subdirs:
        parts = folder.split('_')
        if len(parts) < 3:
            print(f"Skipping folder {folder} due to unexpected name format.")
            continue
        date1, date2 = parts[1], parts[2]
        folder_path = os.path.join(root_dir, folder)
        amp_file = os.path.join(folder_path, base_filename + ".amp")
        cor_file = os.path.join(folder_path, base_filename + ".cor")

        # Check that both the .amp and .cor files (and their XML metadata) exist
        if not (os.path.exists(amp_file) and os.path.exists(amp_file + '.xml')):
            print(f"Skipping folder {folder}: amplitude file or its XML is missing.")
            continue
        if not (os.path.exists(cor_file) and os.path.exists(cor_file + '.xml')):
            print(f"Skipping folder {folder}: coherence file or its XML is missing.")
            continue

        # Load node features only if they haven't been loaded before
        if date1 not in date_to_feature or date2 not in date_to_feature:
            try:
                amp1, amp2 = readAmp(amp_file)
            except Exception as e:
                print(f"Error reading amplitude file in {folder}: {e}")
                continue
            if date1 not in date_to_feature:
                date_to_feature[date1] = amp1.flatten()
            if date2 not in date_to_feature:
                date_to_feature[date2] = amp2.flatten()

        # Always load the edge feature from the coherence file
        try:
            cor_feature = readCor(cor_file)
        except Exception as e:
            print(f"Error reading coherence file in {folder}: {e}")
            continue
        edge_features_list.append(cor_feature.flatten())
        edge_node_pairs.append((date1, date2))
        print(f"Processed folder {folder} with dates {date1} and {date2}.")

    # Create a sorted list of unique dates and a mapping: date -> node ID (starting at 1)
    sorted_dates = sorted(date_to_feature.keys())
    date_to_id = {date: idx+1 for idx, date in enumerate(sorted_dates)}

    # Build the node features array: each row is the flattened feature for a node
    node_features = np.array([date_to_feature[date] for date in sorted_dates])
    # Build the edge features array: each row is the flattened edge feature for an edge
    edge_features = np.array(edge_features_list)

    # Save the node mapping to a text file (each line: "nodeID date")
    mapping_file = os.path.join(save_dir, "node_mapping.txt")
    with open(mapping_file, "w") as f:
        for date in sorted_dates:
            f.write(f"{date_to_id[date]} {date}\n")
    print(f"Saved node mapping to '{mapping_file}'.")

    # Save the node and edge features as NumPy arrays
    node_features_file = os.path.join(save_dir, "node_features.npy")
    edge_features_file = os.path.join(save_dir, "edge_features.npy")
    np.save(node_features_file, node_features)
    np.save(edge_features_file, edge_features)
    print(f"Saved node features to '{node_features_file}' and edge features to '{edge_features_file}'.")

    # Save the edge node pairs (as node IDs) into a text file.
    edge_pairs_file = os.path.join(save_dir, "edge_node_pairs.txt")
    with open(edge_pairs_file, "w") as f:
        for date1, date2 in edge_node_pairs:
            src = date_to_id[date1]
            tgt = date_to_id[date2]
            # Save with a tab separation between source and target node
            f.write(f"{src}\t{tgt}\n")
    print(f"Saved edge node pairs to '{edge_pairs_file}'.")

    # Report counts
    num_nodes = node_features.shape[0]
    num_edges = edge_features.shape[0]
    print(f"Number of nodes: {num_nodes}")
    print(f"Number of edges: {num_edges}")

    # Optionally return the features and mapping information
    return node_features, edge_features, date_to_id, edge_node_pairs

if __name__ == '__main__':
    # Define your root directory containing the "cor_YYYYMMDD_YYYYMMDD" folders.
    root_directory = "/home/zzhu/TGNN_sharing_20250214/merged/cors"
    node_features, edge_features, node_mapping, edge_node_pairs = process_dataset(root_directory, base_filename='b01_16r4alks')
# Out:
# Processed folder cor_20240103_20240115 with dates 20240103 and 20240115.
# Processed folder cor_20240103_20240127 with dates 20240103 and 20240127.
# Processed folder cor_20240103_20240208 with dates 20240103 and 20240208.
# Processed folder cor_20240103_20240220 with dates 20240103 and 20240220.
# Processed folder cor_20240103_20240303 with dates 20240103 and 20240303.
# Processed folder cor_20240103_20240315 with dates 20240103 and 20240315.
# Processed folder cor_20240103_20240327 with dates 20240103 and 20240327.
# Processed folder cor_20240103_20240408 with dates 20240103 and 20240408.
# Processed folder cor_20240103_20240420 with dates 20240103 and 20240420.
# Processed folder cor_20240103_20240502 with dates 20240103 and 20240502.
# Processed folder cor_20240115_20240127 with dates 20240115 and 20240127.
# Processed folder cor_20240115_20240208 with dates 20240115 and 20240208.
# Processed folder cor_20240115_20240220 with dates 20240115 and 20240220.
# Processed folder cor_20240115_20240303 with dates 20240115 and 20240303.
# Processed folder cor_20240115_20240315 with dates 20240115 and 20240315.
# Processed folder cor_20240115_20240327 with dates 20240115 and 20240327.
# Processed folder cor_20240115_20240408 with dates 20240115 and 20240408.
# Processed folder cor_20240115_20240420 with dates 20240115 and 20240420.
# Processed folder cor_20240115_20240502 with dates 20240115 and 20240502.
# Processed folder cor_20240115_20240514 with dates 20240115 and 20240514.
# Processed folder cor_20240127_20240208 with dates 20240127 and 20240208.
# Processed folder cor_20240127_20240220 with dates 20240127 and 20240220.
# Processed folder cor_20240127_20240303 with dates 20240127 and 20240303.
# Processed folder cor_20240127_20240315 with dates 20240127 and 20240315.
# Processed folder cor_20240127_20240327 with dates 20240127 and 20240327.
# Processed folder cor_20240127_20240408 with dates 20240127 and 20240408.
# Processed folder cor_20240127_20240420 with dates 20240127 and 20240420.
# Processed folder cor_20240127_20240502 with dates 20240127 and 20240502.
# Processed folder cor_20240127_20240514 with dates 20240127 and 20240514.
# Processed folder cor_20240127_20240526 with dates 20240127 and 20240526.
# Processed folder cor_20240208_20240220 with dates 20240208 and 20240220.
# Processed folder cor_20240208_20240303 with dates 20240208 and 20240303.
# Processed folder cor_20240208_20240315 with dates 20240208 and 20240315.
# Processed folder cor_20240208_20240327 with dates 20240208 and 20240327.
# Processed folder cor_20240208_20240408 with dates 20240208 and 20240408.
# Processed folder cor_20240208_20240420 with dates 20240208 and 20240420.
# Processed folder cor_20240208_20240502 with dates 20240208 and 20240502.
# Processed folder cor_20240208_20240514 with dates 20240208 and 20240514.
# Processed folder cor_20240208_20240526 with dates 20240208 and 20240526.
# Processed folder cor_20240220_20240303 with dates 20240220 and 20240303.
# Processed folder cor_20240220_20240315 with dates 20240220 and 20240315.
# Processed folder cor_20240220_20240327 with dates 20240220 and 20240327.
# Processed folder cor_20240220_20240408 with dates 20240220 and 20240408.
# Processed folder cor_20240220_20240420 with dates 20240220 and 20240420.
# Processed folder cor_20240220_20240502 with dates 20240220 and 20240502.
# Processed folder cor_20240220_20240514 with dates 20240220 and 20240514.
# Processed folder cor_20240220_20240526 with dates 20240220 and 20240526.
# Processed folder cor_20240220_20240619 with dates 20240220 and 20240619.
# Processed folder cor_20240303_20240315 with dates 20240303 and 20240315.
# Processed folder cor_20240303_20240327 with dates 20240303 and 20240327.
# Processed folder cor_20240303_20240408 with dates 20240303 and 20240408.
# Processed folder cor_20240303_20240420 with dates 20240303 and 20240420.
# Processed folder cor_20240303_20240502 with dates 20240303 and 20240502.
# Processed folder cor_20240303_20240514 with dates 20240303 and 20240514.
# Processed folder cor_20240303_20240526 with dates 20240303 and 20240526.
# Processed folder cor_20240303_20240619 with dates 20240303 and 20240619.
# Processed folder cor_20240303_20240701 with dates 20240303 and 20240701.
# Processed folder cor_20240315_20240327 with dates 20240315 and 20240327.
# Processed folder cor_20240315_20240408 with dates 20240315 and 20240408.
# Processed folder cor_20240315_20240420 with dates 20240315 and 20240420.
# Processed folder cor_20240315_20240502 with dates 20240315 and 20240502.
# Processed folder cor_20240315_20240514 with dates 20240315 and 20240514.
# Processed folder cor_20240315_20240526 with dates 20240315 and 20240526.
# Processed folder cor_20240315_20240619 with dates 20240315 and 20240619.
# Processed folder cor_20240315_20240701 with dates 20240315 and 20240701.
# Processed folder cor_20240315_20240713 with dates 20240315 and 20240713.
# Processed folder cor_20240327_20240408 with dates 20240327 and 20240408.
# Processed folder cor_20240327_20240420 with dates 20240327 and 20240420.
# Processed folder cor_20240327_20240502 with dates 20240327 and 20240502.
# Processed folder cor_20240327_20240514 with dates 20240327 and 20240514.
# Processed folder cor_20240327_20240526 with dates 20240327 and 20240526.
# Processed folder cor_20240327_20240619 with dates 20240327 and 20240619.
# Processed folder cor_20240327_20240701 with dates 20240327 and 20240701.
# Processed folder cor_20240327_20240713 with dates 20240327 and 20240713.
# Processed folder cor_20240327_20240725 with dates 20240327 and 20240725.
# Processed folder cor_20240408_20240420 with dates 20240408 and 20240420.
# Processed folder cor_20240408_20240502 with dates 20240408 and 20240502.
# Processed folder cor_20240408_20240514 with dates 20240408 and 20240514.
# Processed folder cor_20240408_20240526 with dates 20240408 and 20240526.
# Processed folder cor_20240408_20240619 with dates 20240408 and 20240619.
# Processed folder cor_20240408_20240701 with dates 20240408 and 20240701.
# Processed folder cor_20240408_20240713 with dates 20240408 and 20240713.
# Processed folder cor_20240408_20240725 with dates 20240408 and 20240725.
# Processed folder cor_20240408_20240806 with dates 20240408 and 20240806.
# Processed folder cor_20240420_20240502 with dates 20240420 and 20240502.
# Processed folder cor_20240420_20240514 with dates 20240420 and 20240514.
# Processed folder cor_20240420_20240526 with dates 20240420 and 20240526.
# Processed folder cor_20240420_20240619 with dates 20240420 and 20240619.
# Processed folder cor_20240420_20240701 with dates 20240420 and 20240701.
# Processed folder cor_20240420_20240713 with dates 20240420 and 20240713.
# Processed folder cor_20240420_20240725 with dates 20240420 and 20240725.
# Processed folder cor_20240420_20240806 with dates 20240420 and 20240806.
# Processed folder cor_20240420_20240818 with dates 20240420 and 20240818.
# Processed folder cor_20240502_20240514 with dates 20240502 and 20240514.
# Processed folder cor_20240502_20240526 with dates 20240502 and 20240526.
# Processed folder cor_20240502_20240619 with dates 20240502 and 20240619.
# Processed folder cor_20240502_20240701 with dates 20240502 and 20240701.
# Processed folder cor_20240502_20240713 with dates 20240502 and 20240713.
# Processed folder cor_20240502_20240725 with dates 20240502 and 20240725.
# Processed folder cor_20240502_20240806 with dates 20240502 and 20240806.
# Processed folder cor_20240502_20240818 with dates 20240502 and 20240818.
# Processed folder cor_20240502_20240830 with dates 20240502 and 20240830.
# Processed folder cor_20240514_20240526 with dates 20240514 and 20240526.
# Processed folder cor_20240514_20240619 with dates 20240514 and 20240619.
# Processed folder cor_20240514_20240701 with dates 20240514 and 20240701.
# Processed folder cor_20240514_20240713 with dates 20240514 and 20240713.
# Processed folder cor_20240514_20240725 with dates 20240514 and 20240725.
# Processed folder cor_20240514_20240806 with dates 20240514 and 20240806.
# Processed folder cor_20240514_20240818 with dates 20240514 and 20240818.
# Processed folder cor_20240514_20240830 with dates 20240514 and 20240830.
# Processed folder cor_20240514_20240911 with dates 20240514 and 20240911.
# Processed folder cor_20240526_20240619 with dates 20240526 and 20240619.
# Processed folder cor_20240526_20240701 with dates 20240526 and 20240701.
# Processed folder cor_20240526_20240713 with dates 20240526 and 20240713.
# Processed folder cor_20240526_20240725 with dates 20240526 and 20240725.
# Processed folder cor_20240526_20240806 with dates 20240526 and 20240806.
# Processed folder cor_20240526_20240818 with dates 20240526 and 20240818.
# Processed folder cor_20240526_20240830 with dates 20240526 and 20240830.
# Processed folder cor_20240526_20240911 with dates 20240526 and 20240911.
# Processed folder cor_20240526_20240923 with dates 20240526 and 20240923.
# Processed folder cor_20240619_20240701 with dates 20240619 and 20240701.
# Processed folder cor_20240619_20240713 with dates 20240619 and 20240713.
# Processed folder cor_20240619_20240725 with dates 20240619 and 20240725.
# Processed folder cor_20240619_20240806 with dates 20240619 and 20240806.
# Processed folder cor_20240619_20240818 with dates 20240619 and 20240818.
# Processed folder cor_20240619_20240830 with dates 20240619 and 20240830.
# Processed folder cor_20240619_20240911 with dates 20240619 and 20240911.
# Processed folder cor_20240619_20240923 with dates 20240619 and 20240923.
# Processed folder cor_20240619_20241005 with dates 20240619 and 20241005.
# Processed folder cor_20240619_20241017 with dates 20240619 and 20241017.
# Processed folder cor_20240701_20240713 with dates 20240701 and 20240713.
# Processed folder cor_20240701_20240725 with dates 20240701 and 20240725.
# Processed folder cor_20240701_20240806 with dates 20240701 and 20240806.
# Processed folder cor_20240701_20240818 with dates 20240701 and 20240818.
# Processed folder cor_20240701_20240830 with dates 20240701 and 20240830.
# Processed folder cor_20240701_20240911 with dates 20240701 and 20240911.
# Processed folder cor_20240701_20240923 with dates 20240701 and 20240923.
# Processed folder cor_20240701_20241005 with dates 20240701 and 20241005.
# Processed folder cor_20240701_20241017 with dates 20240701 and 20241017.
# Processed folder cor_20240701_20241029 with dates 20240701 and 20241029.
# Processed folder cor_20240713_20240725 with dates 20240713 and 20240725.
# Processed folder cor_20240713_20240806 with dates 20240713 and 20240806.
# Processed folder cor_20240713_20240818 with dates 20240713 and 20240818.
# Processed folder cor_20240713_20240830 with dates 20240713 and 20240830.
# Processed folder cor_20240713_20240911 with dates 20240713 and 20240911.
# Processed folder cor_20240713_20240923 with dates 20240713 and 20240923.
# Processed folder cor_20240713_20241005 with dates 20240713 and 20241005.
# Processed folder cor_20240713_20241017 with dates 20240713 and 20241017.
# Processed folder cor_20240713_20241029 with dates 20240713 and 20241029.
# Processed folder cor_20240713_20241110 with dates 20240713 and 20241110.
# Processed folder cor_20240725_20240806 with dates 20240725 and 20240806.
# Processed folder cor_20240725_20240818 with dates 20240725 and 20240818.
# Processed folder cor_20240725_20240830 with dates 20240725 and 20240830.
# Processed folder cor_20240725_20240911 with dates 20240725 and 20240911.
# Processed folder cor_20240725_20240923 with dates 20240725 and 20240923.
# Processed folder cor_20240725_20241005 with dates 20240725 and 20241005.
# Processed folder cor_20240725_20241017 with dates 20240725 and 20241017.
# Processed folder cor_20240725_20241029 with dates 20240725 and 20241029.
# Processed folder cor_20240725_20241110 with dates 20240725 and 20241110.
# Processed folder cor_20240725_20241122 with dates 20240725 and 20241122.
# Processed folder cor_20240806_20240818 with dates 20240806 and 20240818.
# Processed folder cor_20240806_20240830 with dates 20240806 and 20240830.
# Processed folder cor_20240806_20240911 with dates 20240806 and 20240911.
# Processed folder cor_20240806_20240923 with dates 20240806 and 20240923.
# Processed folder cor_20240806_20241005 with dates 20240806 and 20241005.
# Processed folder cor_20240806_20241017 with dates 20240806 and 20241017.
# Processed folder cor_20240806_20241029 with dates 20240806 and 20241029.
# Processed folder cor_20240806_20241110 with dates 20240806 and 20241110.
# Processed folder cor_20240806_20241122 with dates 20240806 and 20241122.
# Processed folder cor_20240806_20241204 with dates 20240806 and 20241204.
# Processed folder cor_20240818_20240830 with dates 20240818 and 20240830.
# Processed folder cor_20240818_20240911 with dates 20240818 and 20240911.
# Processed folder cor_20240818_20240923 with dates 20240818 and 20240923.
# Processed folder cor_20240818_20241005 with dates 20240818 and 20241005.
# Processed folder cor_20240818_20241017 with dates 20240818 and 20241017.
# Processed folder cor_20240818_20241029 with dates 20240818 and 20241029.
# Processed folder cor_20240818_20241110 with dates 20240818 and 20241110.
# Processed folder cor_20240818_20241122 with dates 20240818 and 20241122.
# Processed folder cor_20240818_20241204 with dates 20240818 and 20241204.
# Processed folder cor_20240818_20241216 with dates 20240818 and 20241216.
# Processed folder cor_20240830_20240911 with dates 20240830 and 20240911.
# Processed folder cor_20240830_20240923 with dates 20240830 and 20240923.
# Processed folder cor_20240830_20241005 with dates 20240830 and 20241005.
# Processed folder cor_20240830_20241017 with dates 20240830 and 20241017.
# Processed folder cor_20240830_20241029 with dates 20240830 and 20241029.
# Processed folder cor_20240830_20241110 with dates 20240830 and 20241110.
# Processed folder cor_20240830_20241122 with dates 20240830 and 20241122.
# Processed folder cor_20240830_20241204 with dates 20240830 and 20241204.
# Processed folder cor_20240830_20241216 with dates 20240830 and 20241216.
# Processed folder cor_20240830_20241228 with dates 20240830 and 20241228.
# Processed folder cor_20240911_20240923 with dates 20240911 and 20240923.
# Processed folder cor_20240911_20241005 with dates 20240911 and 20241005.
# Processed folder cor_20240911_20241017 with dates 20240911 and 20241017.
# Processed folder cor_20240911_20241029 with dates 20240911 and 20241029.
# Processed folder cor_20240911_20241110 with dates 20240911 and 20241110.
# Processed folder cor_20240911_20241122 with dates 20240911 and 20241122.
# Processed folder cor_20240911_20241204 with dates 20240911 and 20241204.
# Processed folder cor_20240911_20241216 with dates 20240911 and 20241216.
# Processed folder cor_20240911_20241228 with dates 20240911 and 20241228.
# Processed folder cor_20240911_20250109 with dates 20240911 and 20250109.
# Processed folder cor_20240923_20241005 with dates 20240923 and 20241005.
# Processed folder cor_20240923_20241017 with dates 20240923 and 20241017.
# Processed folder cor_20240923_20241029 with dates 20240923 and 20241029.
# Processed folder cor_20240923_20241110 with dates 20240923 and 20241110.
# Processed folder cor_20240923_20241122 with dates 20240923 and 20241122.
# Processed folder cor_20240923_20241204 with dates 20240923 and 20241204.
# Processed folder cor_20240923_20241216 with dates 20240923 and 20241216.
# Processed folder cor_20240923_20241228 with dates 20240923 and 20241228.
# Processed folder cor_20240923_20250109 with dates 20240923 and 20250109.
# Processed folder cor_20241005_20241017 with dates 20241005 and 20241017.
# Processed folder cor_20241005_20241029 with dates 20241005 and 20241029.
# Processed folder cor_20241005_20241110 with dates 20241005 and 20241110.
# Processed folder cor_20241005_20241122 with dates 20241005 and 20241122.
# Processed folder cor_20241005_20241204 with dates 20241005 and 20241204.
# Processed folder cor_20241005_20241216 with dates 20241005 and 20241216.
# Processed folder cor_20241005_20241228 with dates 20241005 and 20241228.
# Processed folder cor_20241005_20250109 with dates 20241005 and 20250109.
# Processed folder cor_20241017_20241029 with dates 20241017 and 20241029.
# Processed folder cor_20241017_20241110 with dates 20241017 and 20241110.
# Processed folder cor_20241017_20241122 with dates 20241017 and 20241122.
# Processed folder cor_20241017_20241204 with dates 20241017 and 20241204.
# Processed folder cor_20241017_20241216 with dates 20241017 and 20241216.
# Processed folder cor_20241017_20241228 with dates 20241017 and 20241228.
# Processed folder cor_20241017_20250109 with dates 20241017 and 20250109.
# Processed folder cor_20241029_20241110 with dates 20241029 and 20241110.
# Processed folder cor_20241029_20241122 with dates 20241029 and 20241122.
# Processed folder cor_20241029_20241204 with dates 20241029 and 20241204.
# Processed folder cor_20241029_20241216 with dates 20241029 and 20241216.
# Processed folder cor_20241029_20241228 with dates 20241029 and 20241228.
# Processed folder cor_20241029_20250109 with dates 20241029 and 20250109.
# Processed folder cor_20241110_20241122 with dates 20241110 and 20241122.
# Processed folder cor_20241110_20241204 with dates 20241110 and 20241204.
# Processed folder cor_20241110_20241216 with dates 20241110 and 20241216.
# Processed folder cor_20241110_20241228 with dates 20241110 and 20241228.
# Processed folder cor_20241110_20250109 with dates 20241110 and 20250109.
# Processed folder cor_20241122_20241204 with dates 20241122 and 20241204.
# Processed folder cor_20241122_20241216 with dates 20241122 and 20241216.
# Processed folder cor_20241122_20241228 with dates 20241122 and 20241228.
# Processed folder cor_20241122_20250109 with dates 20241122 and 20250109.
# Processed folder cor_20241204_20241216 with dates 20241204 and 20241216.
# Processed folder cor_20241204_20241228 with dates 20241204 and 20241228.
# Processed folder cor_20241204_20250109 with dates 20241204 and 20250109.
# Processed folder cor_20241216_20241228 with dates 20241216 and 20241228.
# Processed folder cor_20241216_20250109 with dates 20241216 and 20250109.
# Processed folder cor_20241228_20250109 with dates 20241228 and 20250109.
# Saved node mapping to '/home/zzhu/project/DyGLib_TGB/image_data/node_mapping.txt'.
# Saved node features to '/home/zzhu/project/DyGLib_TGB/image_data/node_features.npy' and edge features to '/home/zzhu/project/DyGLib_TGB/image_data/edge_features.npy'.
# Saved edge node pairs to '/home/zzhu/project/DyGLib_TGB/image_data/edge_node_pairs.txt'.
# Number of nodes: 31
# Number of edges: 245
